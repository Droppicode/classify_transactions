# %% [markdown]
# <a href="https://colab.research.google.com/github/Droppicode/classify_transactions/blob/main/classify_transactions_better_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
import json

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
pd.set_option('display.width', 1000)

# Abre base de dados

with open("base_dados.json", "r") as json_file:
    base_dados = json.load(json_file)

categorias = list(base_dados.keys())
# ['SUPERMERCADO', 'RESTAURANTE', 'CASA', 'LOJAS DE DEPARTAMENTO', 'ROUPAS', 'COMBUSTIVEL', 'MANUTENCAO', 'MEDICAMENTOS', 'COSMETICOS', 'PLANO DE SAUDE', 'SERVICOS', 'ASSINATURAS', 'LAZER', 'LUZ', 'AGUA', 'GAS', 'IMPOSTOS', 'TAXAS', 'INVESTIMENTOS', 'EDUCACAO']

# Sujeira para as transacoes

sujeira_prefixos = ['COMPRA', 'PGTO', 'DEBITO', 'CREDITO', 'PIX', 'TED', 'DOC', 'EXTRATO', 'COMPRA ELO', 'COMPRA VISA', 'ELO', 'VISTA']
sujeira_sufixos = ['SP', 'RJ', 'BH', 'CURITIBA', 'MATRIZ', 'FILIAL', 'S.A.', 'LTDA', 'PAGAMENTOS']

def gerar_dataset(qtd_linhas=5000):
    transacoes = []

    for _ in range(qtd_linhas):
        # Escolhe uma loja aleatória
        cat = random.choice(categorias)
        loja = random.choice(base_dados[cat])

        # Gera a descrição suja
        desc = loja
        if random.random() < 0.6: desc = f"{random.choice(sujeira_prefixos)} {desc}"
        if random.random() < 0.4: desc = f"{desc} {random.choice(sujeira_sufixos)}"
        if random.random() < 0.3: desc = f"{desc} {random.randint(10, 9999)}"

        transacoes.append([desc, cat])

    return pd.DataFrame(transacoes, columns=['Descricao', 'Categoria'])

# Executa e salva

print("Gerando 10.000 transações...")
df = gerar_dataset(10000)
df.to_csv('transacoes_train.csv', index=False)

print("Amostra do resultado:")
df
# Out:
# Gerando 10.000 transações...
# Amostra do resultado:
#                        Descricao             Categoria
# 0              EXTRATO STAR PLUS           ASSINATURAS
# 1                  PIX SALESIANA              EDUCACAO
# 2                       SHOPPING  LOJA DE DEPARTAMENTO
# 3              COPEL FILIAL 7087                   LUZ
# 4                 JOHN JOHN 3339  LOJA DE DEPARTAMENTO
# ...                          ...                   ...
# 9995    COMPRA VISA AMEPLAN 6070        PLANO DE SAUDE
# 9996            PIX REVISTA VEJA           ASSINATURAS
# 9997                 TED ANIMALE  LOJA DE DEPARTAMENTO
# 9998  EXTRATO VR COLLEZIONI 3952                ROUPAS
# 9999                   PIX FUNDO         INVESTIMENTOS
#
# [10000 rows x 2 columns]

# %%
# Limpa descrições

df = df[~df['Descricao'].str.contains(r'\bPIX\b', regex=True)]
df['Descricao'] = df['Descricao'].str.findall(r'\b(?!\d+\b)\w{2,}\b').str.join(' ').str.upper().str.strip()
for w in sujeira_prefixos + sujeira_sufixos:
    df['Descricao'] = df['Descricao'].str.replace(w, '')

df['Categoria'] = df['Categoria'].str.upper().str.strip()
# Out:
# /tmp/ipython-input-2147818363.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Descricao'] = df['Descricao'].str.findall(r'\b(?!\d+\b)\w{2,}\b').str.join(' ').str.upper().str.strip()
# /tmp/ipython-input-2147818363.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Descricao'] = df['Descricao'].str.replace(w, '')
# /tmp/ipython-input-2147818363.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Categoria'] = df['Categoria'].str.upper().str.strip()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

X = df['Descricao']
y = df['Categoria']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

model = make_pipeline(
    TfidfVectorizer(),
    RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
)

print("Treinando modelos para todas as colunas...")
model.fit(X_train, y_train)
print("Treino concluído!")
# Out:
# Treinando modelos para todas as colunas...
# Treino concluído!

# %%
y_pred = model.predict(X_test)

df_final = pd.DataFrame({
    'Descricao': X_test,
    'Real': y_test,
    'Previsto': y_pred
})

probas = model.predict_proba(X_test)
max_probas = np.max(probas, axis=1)
df_final['Confianca'] = max_probas

print(df_final.head(10))

print("\nRelatório de Classificação:")
print(classification_report(y_test, y_pred))
# Out:
#                  Descricao                  Real              Previsto  Confianca
# 7784            FAST SHOP                   CASA                  CASA   0.985793
# 7023  PROVEDOR DE INTERNET              SERVICOS              SERVICOS   1.000000
# 2783     MUNDO DAS TINTAS                   CASA                  CASA   0.917347
# 5074         VERO INTERNET              SERVICOS              SERVICOS   1.000000
# 9126            DROGA RAIA          MEDICAMENTOS          MEDICAMENTOS   1.000000
# 2647                  GRF               IMPOSTOS              IMPOSTOS   1.000000
# 8846    AMAZON PRIME VIDEO           ASSINATURAS           ASSINATURAS   1.000000
# 7837     MULTA DE TRANSITO                 TAXAS                 TAXAS   1.000000
# 9290           MANIPULACAO          MEDICAMENTOS          MEDICAMENTOS   1.000000
# 1201         VISA POLISHOP  LOJA DE DEPARTAMENTO  LOJA DE DEPARTAMENTO   0.990000
#
# Relatório de Classificação:
#                       precision    recall  f1-score   support
#
#                 AGUA       1.00      1.00      1.00        90
#          ASSINATURAS       1.00      0.99      0.99        93
#                 CASA       1.00      0.97      0.98        93
#           COSMETICOS       1.00      1.00      1.00        96
#             EDUCACAO       1.00      1.00      1.00        96
#                  GAS       1.00      1.00      1.00        84
#             IMPOSTOS       1.00      1.00      1.00        98
#        INVESTIMENTOS       1.00      1.00      1.00        92
#                LAZER       1.00      1.00      1.00       122
# LOJA DE DEPARTAMENTO       1.00      0.99      0.99        78
#                  LUZ       1.00      1.00      1.00        97
#           MANUTENCAO       1.00      1.00      1.00        86
#         MEDICAMENTOS       1.00      1.00      1.00       100
#       PLANO DE SAUDE       1.00      0.98      0.99        99
#          RESTAURANTE       1.00      0.98      0.99        93
#               ROUPAS       1.00      1.00      1.00        89
#             SERVICOS       1.00      1.00      1.00        91
#         SUPERMERCADO       1.00      0.98      0.99        97
#                TAXAS       0.88      1.00      0.94        95
#           TRANSPORTE       1.00      0.98      0.99       108
#
#             accuracy                           0.99      1897
#            macro avg       0.99      0.99      0.99      1897
#         weighted avg       0.99      0.99      0.99      1897

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=42))])

# %%
df = pd.read_excel('teste.xlsx')
df['Descricao'] = df['Descricao'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df['Categoria'] = df['Categoria'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

df = df[~df['Descricao'].str.contains(r'\bPIX\b', regex=True)]
df = df[~df['Categoria'].str.contains(r'\bOUTROS\b', regex=True)]
df['Descricao'] = df['Descricao'].str.findall(r'\b(?!\d+\b)\w{2,}\b').str.join(' ').str.upper().str.strip()
for w in sujeira_prefixos + sujeira_sufixos:
    df['Descricao'] = df['Descricao'].str.replace(w, '')

y_pred = model.predict(df['Descricao'])

df_final = pd.DataFrame({
    'Descricao': df['Descricao'],
    'Real': df['Categoria'],
    'Previsto': y_pred
})

probas = model.predict_proba(df['Descricao'])
max_probas = np.max(probas, axis=1)
df_final['Confianca'] = max_probas

print(df_final)

print("\nRelatório de Classificação:")
print(classification_report(df['Categoria'], y_pred))
# Out:
#                                           Descricao                   Real              Previsto  Confianca
# 0                                    PADARIA MONACO           SUPERMERCADO           RESTAURANTE   0.910000
# 3                                         MED FARMA           MEDICAMENTOS          MEDICAMENTOS   1.000000
# 4                                      MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 5                              EMPORIO VILA NATURAL           SUPERMERCADO          SUPERMERCADO   0.510000
# 6                                      MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 8      PAGTO ELETRON COBRANCA SUPERGASBRAS ENERGIA                     GAS                   GAS   1.000000
# 9                                       ATACADAO AS           SUPERMERCADO          SUPERMERCADO   0.960000
# 10                      CONTA DE LUZ BRADESCO CPFL                     LUZ                   LUZ   0.950000
# 11                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 12                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 13                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 14               PAGTO ELETRON COBRANCA INTERMEDICA         PLANO DE SAUDE        PLANO DE SAUDE   0.570000
# 16                                REST FRANGOASSADO            RESTAURANTE           RESTAURANTE   0.930000
# 17                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 18                                    POGERE FRIOS            SUPERMERCADO          SUPERMERCADO   1.000000
# 19                               INSTITUTO CANDOMBA               EDUCACAO              EDUCACAO   0.880000
# 20                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 21                                           DROGAL           MEDICAMENTOS          MEDICAMENTOS   1.000000
# 22                                    DROGARIASANTA           MEDICAMENTOS                 TAXAS   0.513323
# 23                                MARAVILHAS DO LAR                   CASA                  CASA   1.000000
# 24            PAGUE FACIL BRADESCO RECARGA PRE PAGO               SERVICOS              SERVICOS   0.530000
# 31                                     POGERE FRIOS           SUPERMERCADO          SUPERMERCADO   1.000000
# 32                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 33                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 34                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 35                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 36                              AUTO POSTO CAMPINAS            COMBUSTIVEL            MANUTENCAO   0.990000
# 37   PAGTO ELETRON COBRANCA SERENO NEGOCIOS IMOB ME                   CASA                 TAXAS   0.513323
# 38                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 39                             FOGAO MINEIRO RESTAU            RESTAURANTE           RESTAURANTE   1.000000
# 40                                      ATACADAO AS           SUPERMERCADO          SUPERMERCADO   0.960000
# 42                              DROGARIA SAO PAULOS           MEDICAMENTOS          MEDICAMENTOS   0.910000
# 44                                      REDE APOLLO            COMBUSTIVEL                 TAXAS   0.513323
# 45                                          RIACHU                  ROUPAS  LOJA DE DEPARTAMENTO   1.000000
# 46                                          JIN JIN            RESTAURANTE           RESTAURANTE   0.830000
# 47                                    PADARIA ALEMA           SUPERMERCADO           RESTAURANTE   0.910000
# 50              CONTA DE AGUA ESGOTO BRADESCO SABE                    AGUA                  AGUA   0.960000
# 51                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 52                                      GOOD OPTICA               SERVICOS          SUPERMERCADO   0.540000
# 53                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 54                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 55                                COSMETICOS ARAUJO             COSMETICOS          SUPERMERCADO   1.000000
# 56                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 58              CONTA DE AGUA ESGOTO BRADESCO SABE                    AGUA                  AGUA   0.960000
# 59                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 60                                         RAIA2254           MEDICAMENTOS                 TAXAS   0.513323
# 61                               INSTITUTO CANDOMBA               EDUCACAO              EDUCACAO   0.880000
# 62                                    PADARIA ALEMA           SUPERMERCADO           RESTAURANTE   0.910000
# 63            PAGUE FACIL BRADESCO RECARGA PRE PAGO               SERVICOS              SERVICOS   0.530000
# 66                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 69                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 70                                       AS DE OURO                   CASA                 TAXAS   0.480000
# 71                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 72                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 77                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 78     PAGTO ELETRON COBRANCA SUPERGASBRAS ENERGIA                     GAS                   GAS   1.000000
# 79                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 80                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 81                      CONTA DE LUZ BRADESCO CPFL                     LUZ                   LUZ   0.950000
# 82                                     POGERE FRIOS           SUPERMERCADO          SUPERMERCADO   1.000000
# 83                 PAGTO ELETRON COBRANCA BANCO CSE                  TAXAS         INVESTIMENTOS   0.670000
# 84                                   CASA SAO PEDRO                   CASA        PLANO DE SAUDE   0.540000
# 85                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 86                                 AUTO BAN JUNDIAI                  TAXAS            MANUTENCAO   0.990000
# 87                             AUTO POSTO LM DE CAM            COMBUSTIVEL            MANUTENCAO   0.840000
# 88                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 89            PAGUE FACIL BRADESCO RECARGA PRE PAGO               SERVICOS              SERVICOS   0.530000
# 91                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 92                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 93                                GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 95                             EMPORIO VILA NATURAL           SUPERMERCADO          SUPERMERCADO   0.510000
# 96                                     MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 99       PAGTO ELETRON COBRANCA SERENO NEGOCIOS IMO                   CASA                 TAXAS   0.513323
# 100                              INSTITUTO CANDOMBA               EDUCACAO              EDUCACAO   0.880000
# 101                                    MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 103                                    MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 105                               GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 108                                 MP EMEFVILLAGIO               EDUCACAO                 TAXAS   0.513323
# 109                                    MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 110           PAGUE FACIL BRADESCO RECARGA PRE PAGO               SERVICOS              SERVICOS   0.530000
# 111                   PAGTO ELETRON COBRANCA MIDWAY  LOJAS DE DEPARTAMENTO                ROUPAS   1.000000
# 112                               GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 113                            EMPORIO VILA NATURAL           SUPERMERCADO          SUPERMERCADO   0.510000
# 114                               GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 115                               GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 116                               GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 117                                    MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
# 125             CONTA DE AGUA ESGOTO BRADESCO SABE                    AGUA                  AGUA   0.960000
# 126                               GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 128                               GOOD BOM LOJA HOR           SUPERMERCADO          SUPERMERCADO   1.000000
# 129                                    MEUMARKET24H           SUPERMERCADO          SUPERMERCADO   1.000000
#
# Relatório de Classificação:
#                        precision    recall  f1-score   support
#
#                  AGUA       1.00      1.00      1.00         3
#                  CASA       1.00      0.20      0.33         5
#           COMBUSTIVEL       0.00      0.00      0.00         3
#            COSMETICOS       0.00      0.00      0.00         1
#              EDUCACAO       1.00      0.75      0.86         4
#                   GAS       1.00      1.00      1.00         2
#         INVESTIMENTOS       0.00      0.00      0.00         0
#  LOJA DE DEPARTAMENTO       0.00      0.00      0.00         0
# LOJAS DE DEPARTAMENTO       0.00      0.00      0.00         1
#                   LUZ       1.00      1.00      1.00         2
#            MANUTENCAO       0.00      0.00      0.00         0
#          MEDICAMENTOS       1.00      0.60      0.75         5
#        PLANO DE SAUDE       0.50      1.00      0.67         1
#           RESTAURANTE       0.50      1.00      0.67         3
#                ROUPAS       0.00      0.00      0.00         1
#              SERVICOS       1.00      0.80      0.89         5
#          SUPERMERCADO       0.96      0.94      0.95        53
#                 TAXAS       0.00      0.00      0.00         2
#
#              accuracy                           0.79        91
#             macro avg       0.50      0.46      0.45        91
#          weighted avg       0.87      0.79      0.81        91
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
